# %% [markdown]
# <a href="https://colab.research.google.com/github/zinakhazaee/Visualization/blob/main/3D_Cube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
axes = [6, 6, 6]

data = np.ones(axes, dtype='bool')

# %%
alpha = 0.8

# %%
colors = np.empty(axes + [4], dtype=np.float32)

#colors[:] = [1, 1, 0, alpha]

# %%
colors[0] = [0, 0, 0, alpha]
colors[1] = [0, 0, 1, alpha]
colors[2] = [0, 1, 0, alpha]
colors[3] = [1, 0, 0, alpha]
colors[4] = [1, 1, 0, alpha]
colors[5] = [1, 1, 1, alpha]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.voxels(data, facecolors=colors, edgecolors='white', shade=True )

plt.show()
